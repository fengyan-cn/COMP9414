# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_excel("data.xlsx")
df.drop(["Date", "Time"], inplace=True, axis=1)
df.head()
# Out:
#    CO(GT)  PT08.S1(CO)  NMHC(GT)   C6H6(GT)  PT08.S2(NMHC)  NOx(GT)  \
# 0     2.6      1360.00       150  11.881723        1045.50    166.0
# 1     2.0      1292.25       112   9.397165         954.75    103.0
# 2     2.2      1402.00        88   8.997817         939.25    131.0
# 3     2.2      1375.50        80   9.228796         948.25    172.0
# 4     1.6      1272.25        51   6.518224         835.50    131.0
#
#    PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)      T         RH  \
# 0       1056.25    113.0       1692.00      1267.50  13.60  48.875001
# 1       1173.75     92.0       1558.75       972.25  13.30  47.700000
# 2       1140.00    114.0       1554.50      1074.00  11.90  53.975000
# 3       1092.00    122.0       1583.75      1203.25  11.00  60.000000
# 4       1205.00    116.0       1490.00      1110.00  11.15  59.575001
#
#          AH
# 0  0.757754
# 1  0.725487
# 2  0.750239
# 3  0.786713
# 4  0.788794

# %%
def missvalue_pre(data):
    feature_columns = data.columns.tolist()
    sample_num = data.shape[0]
    missvalue = []
    for col in feature_columns:
        sum_col = (data[col] <  0).sum()
        missvalue.append(sum_col / sample_num)
    miss_value = pd.Series(missvalue, index=feature_columns)
    print(miss_value)

missvalue_pre(df)
# Out:
# CO(GT)           0.189639
# PT08.S1(CO)      0.043790
# NMHC(GT)         0.900335
# C6H6(GT)         0.043790
# PT08.S2(NMHC)    0.043790
# NOx(GT)          0.188203
# PT08.S3(NOx)     0.043790
# NO2(GT)          0.188562
# PT08.S4(NO2)     0.043790
# PT08.S5(O3)      0.043790
# T                0.045465
# RH               0.043790
# AH               0.043790
# dtype: float64

# %% [markdown]
# ###### 可以看到，不同列中缺失值占比不同

# %%
fill_cols = ["PT08.S1(CO)", "C6H6(GT)", "PT08.S2(NMHC)", "PT08.S3(NOx)", "PT08.S4(NO2)", "PT08.S5(O3)", "T", "RH", "AH"]

def data_process(df):
    for col in fill_cols:
        fill_value = df.loc[df[col] >= 0, col].mean()
        df.loc[df[col] < 0, col] = fill_value
    df.loc[df["NMHC(GT)"] == -200, "NMHC(GT)"] = 0
    return df

df = data_process(df)

# %%
missvalue_pre(df)
# Out:
# CO(GT)           0.189639
# PT08.S1(CO)      0.000000
# NMHC(GT)         0.000000
# C6H6(GT)         0.000000
# PT08.S2(NMHC)    0.000000
# NOx(GT)          0.188203
# PT08.S3(NOx)     0.000000
# NO2(GT)          0.188562
# PT08.S4(NO2)     0.000000
# PT08.S5(O3)      0.000000
# T                0.000000
# RH               0.000000
# AH               0.000000
# dtype: float64

# %% [markdown]
# ##### 为两个任务创建数据集

# %%
df_preCO_train = df[df["CO(GT)"] != -200]
df_preNOx_train = df[df["NOx(GT)"] != - 200]
df_preCO_test = df[df["CO(GT)"] == -200].drop(["CO(GT)"], axis=1)
df_preNOx_test = df[df["NOx(GT)"] == -200].drop(["NOx(GT)"], axis=1)

# %%
missvalue_pre(df_preCO_train), missvalue_pre(df_preNOx_train)
# Out:
# CO(GT)           0.000000
# PT08.S1(CO)      0.000000
# NMHC(GT)         0.000000
# C6H6(GT)         0.000000
# PT08.S2(NMHC)    0.000000
# NOx(GT)          0.056696
# PT08.S3(NOx)     0.000000
# NO2(GT)          0.057139
# PT08.S4(NO2)     0.000000
# PT08.S5(O3)      0.000000
# T                0.000000
# RH               0.000000
# AH               0.000000
# dtype: float64
# CO(GT)           0.058364
# PT08.S1(CO)      0.000000
# NMHC(GT)         0.000000
# C6H6(GT)         0.000000
# PT08.S2(NMHC)    0.000000
# NOx(GT)          0.000000
# PT08.S3(NOx)     0.000000
# NO2(GT)          0.000442
# PT08.S4(NO2)     0.000000
# PT08.S5(O3)      0.000000
# T                0.000000
# RH               0.000000
# AH               0.000000
# dtype: float64
# (None, None)

# %% [markdown]
# ###### 首先继续对两个数据集做填充

# %%
fill_cols_CO = ["NOx(GT)", "NO2(GT)"]
fill_cols_NOx = ["CO(GT)", "NO2(GT)"]
for col in fill_cols_CO:
    fill_value = df_preCO_train.loc[df_preCO_train[col] >= 0, col].mean()
    df_preCO_train.loc[df_preCO_train[col] < 0, col] = fill_value
for col in fill_cols_NOx:
    fill_value = df_preNOx_train.loc[df_preNOx_train[col] >= 0, col].mean()
    df_preNOx_train.loc[df_preNOx_train[col] < 0, col] = fill_value

# %% [markdown]
# ##### 现在数据集填充完毕

# %% [markdown]
# ###### 处理分类预测数据集

# %%
threshold = df_preCO_train["CO(GT)"].mean()
threshold
# Out:
# 2.1469511294847186

# %%
df_preCO_train["target"] = np.where(df_preCO_train["CO(GT)"] > threshold, 1, 0)
df_preCO_train.drop(["CO(GT)"], axis=1, inplace=True)
df_preNOx_train.rename(columns={"NOx(GT)":"target"}, inplace=True)
# Out:
# C:\Users\learn\AppData\Local\Temp\ipykernel_10820\2371055993.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_preCO_train["target"] = np.where(df_preCO_train["CO(GT)"] > threshold, 1, 0)
# C:\Users\learn\AppData\Local\Temp\ipykernel_10820\2371055993.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_preCO_train.drop(["CO(GT)"], axis=1, inplace=True)
# C:\Users\learn\AppData\Local\Temp\ipykernel_10820\2371055993.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %% [markdown]
# ###### 处理回归预测数据集

# %% [markdown]
# ### 开始找到异常点并进行替代

# %%
df_preCO_train.shape, df_preNOx_train.shape
# Out:
# ((6773, 13), (6785, 13))

# %%
def findoutliners(X, sigma=3):
    outliners = []
    for col in X.columns:
        mean = np.mean(X[col])
        std = np.std(X[col])
        for i, val in enumerate(X[col]):
            if np.abs((val - mean) / std) > sigma:
                outliners.append((col, i, val))
    return outliners

def handle_outliers(df, target_col):
    df = df.reset_index(drop=True)
    outliers = findoutliners(df)
    print("Outliers before handling:", outliers)
    for col, index, val in outliers:
        if col != target_col:
            mean = np.mean(df[col])
            df.at[index, col] = mean
    outliers = findoutliners(df)
    # print("Outliers after handling:", outliers)

# %%
handle_outliers(df_preCO_train, "target")

handle_outliers(df_preNOx_train, "target")
# Out:
# Outliers before handling: [('PT08.S1(CO)', 23, 1775.5), ('PT08.S1(CO)', 46, 1843.0), ('PT08.S1(CO)', 91, 1807.5), ('PT08.S1(CO)', 92, 1898.0), ('PT08.S1(CO)', 401, 1757.25), ('PT08.S1(CO)', 604, 1765.0), ('PT08.S1(CO)', 605, 1874.5), ('PT08.S1(CO)', 606, 1746.25), ('PT08.S1(CO)', 651, 1746.75), ('PT08.S1(CO)', 777, 1771.25), ('PT08.S1(CO)', 788, 1760.6666666667), ('PT08.S1(CO)', 1024, 1754.0), ('PT08.S1(CO)', 1116, 1762.75), ('PT08.S1(CO)', 3420, 1747.25), ('PT08.S1(CO)', 3421, 1757.25), ('PT08.S1(CO)', 3531, 1883.75), ('PT08.S1(CO)', 3532, 1834.5), ('PT08.S1(CO)', 3533, 1758.5), ('PT08.S1(CO)', 3578, 1807.75), ('PT08.S1(CO)', 3646, 1816.25), ('PT08.S1(CO)', 3647, 1823.5), ('PT08.S1(CO)', 3648, 1744.0), ('PT08.S1(CO)', 3669, 1821.75), ('PT08.S1(CO)', 3670, 1907.75), ('PT08.S1(CO)', 3831, 1751.0), ('PT08.S1(CO)', 3833, 1778.0), ('PT08.S1(CO)', 3870, 1882.0), ('PT08.S1(CO)', 3893, 1869.75), ('PT08.S1(CO)', 3894, 1774.25), ('PT08.S1(CO)', 4089, 1802.0), ('PT08.S1(CO)', 4205, 1738.25), (
# ...

# %%
df_preCO_train.shape, df_preNOx_train.shape
# Out:
# ((6773, 13), (6785, 13))

# %% [markdown]
# #### 接下来需要对训练集和测试集做一致性处理

# %%
from sklearn.model_selection import train_test_split

# %%
y_preNOx_target = df_preNOx_train["target"]
df_preNOx_train.drop(["target"], axis=1, inplace=True)
y_preCO_target = df_preCO_train["target"]
df_preCO_train.drop(["target"], axis=1, inplace=True)
# Out:
# C:\Users\learn\AppData\Local\Temp\ipykernel_10820\207428639.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_preNOx_train.drop(["target"], axis=1, inplace=True)
# C:\Users\learn\AppData\Local\Temp\ipykernel_10820\207428639.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_preCO_train.drop(["target"], axis=1, inplace=True)

# %%
df_preCO_train_1, df_preCO_valid_1, y_preCO, y_preCO_valid = train_test_split(df_preCO_train, y_preCO_target, test_size=0.2, random_state=42, shuffle=True)
df_preNOx_train_1, df_preNOx_valid_1, y_preNOx, y_preNOx_valid = train_test_split(df_preNOx_train, y_preNOx_target, test_size=0.2, random_state=42, shuffle=True)

# %%
def fill_value(df, df_test=None):
    feature_columns = df.columns
    if not df_test.empty:
        for col in feature_columns:
            df_test.loc[df_test[col] < 0, col] = df[col].mean()

fill_value(df_preCO_train_1, df_preCO_valid_1)
fill_value(df_preNOx_train_1, df_preNOx_valid_1)

# %%
from sklearn.preprocessing import MinMaxScaler

def minmax(df, df_test=None):
    feature_columns = df.columns
    minmaxscaler = MinMaxScaler()
    X = minmaxscaler.fit_transform(df)
    data = pd.DataFrame(X, columns=feature_columns)
    if not df_test.empty:
        df_test = minmaxscaler.transform(df_test)
        data_test = pd.DataFrame(df_test, columns=feature_columns)
    return data, data_test

data_preNOX, data_preNOX_valid = minmax(df_preNOx_train_1, df_preNOx_valid_1)
data_preCO, data_preCO_valid = minmax(df_preCO_train_1, df_preCO_valid_1)

# %%
data_preNOX.shape, data_preNOX_valid.shape, y_preNOx.shape, y_preNOx_valid.shape
# Out:
# ((5428, 12), (1357, 12), (5428,), (1357,))

# %%
import seaborn as sns

# %% [markdown]
# ###### 可以用regplot查看连续型与连续型，协方差矩阵查看回归任务的关系； 用小提琴图查看回归问题之间的关系

# %% [markdown]
# ## 数据处理完成

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.models import load_model
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, accuracy_score, mean_squared_error
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import EarlyStopping

# %% [markdown]
# ## 接下来是分类任务

# %%
data_preNOX_valid.shape, data_preNOX.shape, y_preNOx.shape, y_preNOx_valid.shape
# Out:
# ((1357, 12), (5428, 12), (5428,), (1357,))

# %%
poly = PolynomialFeatures(degree=2)
X = poly.fit_transform(data_preCO)
X_valid = poly.transform(data_preCO_valid)
y = y_preCO.reset_index(drop=True)
y_valid = y_preCO_valid.reset_index(drop=True)

# %%
model = Sequential()
# model.add(Dense(128, activation='relu', input_shape=(poly_X.shape[1],), kernel_regularizer=l2(0.01)))
model.add(Dense(128, activation='relu', input_shape=(X.shape[1],), kernel_regularizer=l2(0.01)))
# model.add(Dropout(0.5))
model.add(Dense(256, activation="relu", kernel_regularizer=l2(0.01)))
# model.add(Dropout(0.5))
model.add(Dense(128, activation="relu", kernel_regularizer=l2(0.01)))
# model.add(Dropout(0.5))
model.add(Dense(64, activation="relu", kernel_regularizer=l2(0.01)))
# model.add(Dropout(0.5))
# model.add(Dense(8, activation="relu", kernel_regularizer=l2(0.01)))
# model.add(Dropout(0.5))
model.add(Dense(1, activation='sigmoid'))
early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=15,
    restore_best_weights=True
)
model.compile(optimizer=Adam(), loss="binary_crossentropy", metrics=["accuracy"])
history = model.fit(X, y, epochs=500, batch_size=128, validation_data=(X_valid, y_valid), callbacks=[early_stopping])
# Out:
# Epoch 1/500
# 43/43 [==============================] - 1s 4ms/step - loss: 4.0316 - accuracy: 0.8223 - val_loss: 2.4135 - val_accuracy: 0.9063
# Epoch 2/500
# 43/43 [==============================] - 0s 2ms/step - loss: 1.6777 - accuracy: 0.9164 - val_loss: 1.1159 - val_accuracy: 0.9159
# Epoch 3/500
# 43/43 [==============================] - 0s 2ms/step - loss: 0.8508 - accuracy: 0.9153 - val_loss: 0.6380 - val_accuracy: 0.9210
# Epoch 4/500
# 43/43 [==============================] - 0s 2ms/step - loss: 0.5501 - accuracy: 0.9157 - val_loss: 0.4660 - val_accuracy: 0.9210
# Epoch 5/500
# 43/43 [==============================] - 0s 2ms/step - loss: 0.4320 - accuracy: 0.9208 - val_loss: 0.3975 - val_accuracy: 0.9262
# Epoch 6/500
# 43/43 [==============================] - 0s 2ms/step - loss: 0.3891 - accuracy: 0.9121 - val_loss: 0.3643 - val_accuracy: 0.9218
# Epoch 7/500
# ...

# %%
plt.figure(figsize=(15, 8))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='train_acc')
plt.plot(history.history['val_accuracy'], label='val_acc')
plt.xlabel('Epochs')
plt.ylabel('accuracy')
plt.legend()
plt.show()

# %%
predict = (model.predict(X_valid) > 0.5).astype('int')
accuracy_score(y_valid.values, predict)
# Out:
# 43/43 [==============================] - 0s 660us/step
# 0.9328413284132842

# %%
from sklearn.metrics import confusion_matrix

# %%
cm = confusion_matrix(y_valid, predict)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Predicted 0', 'Predicted 1'], yticklabels=['True 0', 'True 1'])
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()

# %%
model.save("classification_model.h5")
# Out:
# c:\ProgramData\anaconda3\envs\tensorflow\lib\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# ## 回归问题

# %%
poly = PolynomialFeatures(degree=2)
X = poly.fit_transform(data_preNOX)
X_valid = poly.transform(data_preNOX_valid)
y = y_preNOx.reset_index(drop=True)
y_valid = y_preNOx_valid.reset_index(drop=True)

# %%
model = Sequential()

model.add(Dense(256, activation='relu', input_shape=(X.shape[1],), kernel_regularizer=l2(0.01)))
# model.add(Dropout(0.5))
model.add(Dense(128, activation='relu', kernel_regularizer=l2(0.01)))
# model.add(Dropout(0.5))
model.add(Dense(64, activation='relu', kernel_regularizer=l2(0.01)))
# model.add(Dropout(0.5))
model.add(Dense(32, activation='relu', kernel_regularizer=l2(0.01)))
# model.add(Dropout(0.5))
model.add(Dense(16, activation='relu', kernel_regularizer=l2(0.01)))
# model.add(Dropout(0.5))
model.add(Dense(1))
early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=15,
    restore_best_weights=True
)
model.compile(optimizer=Adam(), loss='mean_squared_error', metrics=['mean_absolute_error'])
history = model.fit(X, y, epochs=500, batch_size=128, validation_data=(X_valid, y_valid), callbacks=early_stopping)
# Out:
# Epoch 1/500
# 43/43 [==============================] - 1s 4ms/step - loss: 98377.0234 - mean_absolute_error: 228.9881 - val_loss: 46442.3594 - val_mean_absolute_error: 138.2757
# Epoch 2/500
# 43/43 [==============================] - 0s 2ms/step - loss: 30660.3750 - mean_absolute_error: 134.5904 - val_loss: 21356.7773 - val_mean_absolute_error: 116.1519
# Epoch 3/500
# 43/43 [==============================] - 0s 2ms/step - loss: 16627.4512 - mean_absolute_error: 96.9337 - val_loss: 11014.5342 - val_mean_absolute_error: 72.0153
# Epoch 4/500
# 43/43 [==============================] - 0s 2ms/step - loss: 8922.4912 - mean_absolute_error: 61.9110 - val_loss: 8054.5908 - val_mean_absolute_error: 58.5024
# Epoch 5/500
# 43/43 [==============================] - 0s 2ms/step - loss: 7515.0942 - mean_absolute_error: 56.8234 - val_loss: 7388.8086 - val_mean_absolute_error: 55.9633
# Epoch 6/500
# ...

# %%
plt.figure(figsize=(8, 6))
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(np.linspace(0, len(y_valid), len(y_valid)), y_valid.values, label="MLP actual NOx(GT) values(validation)")
plt.plot(np.linspace(0, len(y_valid), len(y_valid)), model.predict(X_valid), color="orange", label="MLP predict NOx(GT) values(validation)")
plt.xlabel('Epochs')
plt.ylabel('accuracy')
plt.legend()
plt.show()
# Out:
# 43/43 [==============================] - 0s 704us/step

# %%
RMSE = np.sqrt(mean_squared_error(y_valid, model.predict(X_valid)))
MAE = mean_absolute_error(y_valid, model.predict(X_valid))
RMSE, MAE, len(y_valid)
# Out:
# ...
# 43/43 [==============================] - 0s 592us/step
# (48.7541829817177, 30.181546865391574, 1357)

# %%
model.save("regression_model.h5")
# Out:
# c:\ProgramData\anaconda3\envs\tensorflow\lib\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
