# %% [markdown]
# #### z5471284 HONGYE ZHOU

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_excel("AirQualityUCI _ Students.xlsx")
df.drop(["Date", "Time"], inplace=True, axis=1)
df.head()
# Out:
#    CO(GT)  PT08.S1(CO)  NMHC(GT)   C6H6(GT)  PT08.S2(NMHC)  NOx(GT)  \
# 0     2.6      1360.00       150  11.881723        1045.50    166.0
# 1     2.0      1292.25       112   9.397165         954.75    103.0
# 2     2.2      1402.00        88   8.997817         939.25    131.0
# 3     2.2      1375.50        80   9.228796         948.25    172.0
# 4     1.6      1272.25        51   6.518224         835.50    131.0
#
#    PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)      T         RH  \
# 0       1056.25    113.0       1692.00      1267.50  13.60  48.875001
# 1       1173.75     92.0       1558.75       972.25  13.30  47.700000
# 2       1140.00    114.0       1554.50      1074.00  11.90  53.975000
# 3       1092.00    122.0       1583.75      1203.25  11.00  60.000000
# 4       1205.00    116.0       1490.00      1110.00  11.15  59.575001
#
#          AH
# 0  0.757754
# 1  0.725487
# 2  0.750239
# 3  0.786713
# 4  0.788794

# %% [markdown]
# #### Check for missing data

# %%
def missvalue_pre(data):
    feature_columns = data.columns.tolist()
    sample_num = data.shape[0]
    missvalue = []
    for col in feature_columns:
        sum_col = (data[col] <  0).sum()
        missvalue.append(sum_col / sample_num)
    miss_value = pd.Series(missvalue, index=feature_columns)
    print(miss_value)

missvalue_pre(df)
# Out:
# CO(GT)           0.189639
# PT08.S1(CO)      0.043790
# NMHC(GT)         0.900335
# C6H6(GT)         0.043790
# PT08.S2(NMHC)    0.043790
# NOx(GT)          0.188203
# PT08.S3(NOx)     0.043790
# NO2(GT)          0.188562
# PT08.S4(NO2)     0.043790
# PT08.S5(O3)      0.043790
# T                0.045465
# RH               0.043790
# AH               0.043790
# dtype: float64

# %% [markdown]
# ###### we can find that, the proportion of missing values varies in different columns

# %%
df.describe()
# Out:
#             CO(GT)  PT08.S1(CO)     NMHC(GT)     C6H6(GT)  PT08.S2(NMHC)  \
# count  8358.000000  8358.000000  8358.000000  8358.000000    8358.000000
# mean    -36.187928  1038.533411  -158.119167     0.894268     889.323901
# std      79.260156   338.349674   141.931963    43.609487     350.473599
# min    -200.000000  -200.000000  -200.000000  -200.000000    -200.000000
# 25%       0.500000   915.062500  -200.000000     3.968875     709.000000
# 50%       1.500000  1048.500000  -200.000000     7.826424     892.000000
# 75%       2.600000  1215.687500  -200.000000    13.636091    1104.750000
# max      11.900000  2007.750000  1189.000000    63.741476    2214.000000
#
#            NOx(GT)  PT08.S3(NOx)      NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# count  8358.000000   8358.000000  8358.000000   8358.000000  8358.000000
# mean    162.607933    790.043631    53.912228   1382.696877   968.419987
# std     260.322621    327.590979   130.150259    479.299713   464.837162
# min    -200.000000   -200.000000  -200.000000   -200.000000  -200.000000
# 25%      45.000000    634.250000    49.000000   1177.500000   692.062500
# 50%     136.000000    793.000000    95.000000   1442.500000   940.125000
# 75%     282.000000    958.687500   132.000000   1658.187500  1251.750000
# max    1479.000000   2682.750000   339.700000   2775.000000  2522.750000
#
#                  T           RH           AH
# count  8358.000000  8358.000000  8358.000000
# mean      8.713360    38.201273    -7.780588
# std      45.516939    53.678637    41.139234
# min    -200.000000  -200.000000  -200.000000
# 25%      10.450000    33.974999     0.675253
# 50%      17.225000    48.137500     0.971383
# 75%      24.075000    61.593750     1.307486
# max      44.600000    87.174999     2.231036

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8358 entries, 0 to 8357
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CO(GT)         8358 non-null   float64
#  1   PT08.S1(CO)    8358 non-null   float64
#  2   NMHC(GT)       8358 non-null   int64
#  3   C6H6(GT)       8358 non-null   float64
#  4   PT08.S2(NMHC)  8358 non-null   float64
#  5   NOx(GT)        8358 non-null   float64
#  6   PT08.S3(NOx)   8358 non-null   float64
#  7   NO2(GT)        8358 non-null   float64
#  8   PT08.S4(NO2)   8358 non-null   float64
#  9   PT08.S5(O3)    8358 non-null   float64
#  10  T              8358 non-null   float64
#  11  RH             8358 non-null   float64
#  12  AH             8358 non-null   float64
# dtypes: float64(12), int64(1)
# memory usage: 849.0 KB

# %%
df["NMHC(GT)"].value_counts()
# Out:
# NMHC(GT)
# -200    7525
#  66       14
#  40        9
#  93        8
#  29        8
#         ...
#  721       1
#  787       1
#  307       1
#  200       1
#  339       1
# Name: count, Length: 406, dtype: int64

# %% [markdown]
# #### we can find that the type of nmhc(gt) is int and almost 90% of its value are missing
# #### in fact, i think its can be deleted or be replaced by a new value to represent all missing values
# #### There are not many missing values for other features, so we use the average value to fill in.

# %%
fill_cols = ["PT08.S1(CO)", "C6H6(GT)", "PT08.S2(NMHC)", "PT08.S3(NOx)", "PT08.S4(NO2)", "PT08.S5(O3)", "T", "RH", "AH"]

def data_process(df):
    for col in fill_cols:
        fill_value = df.loc[df[col] >= 0, col].mean()
        df.loc[df[col] < 0, col] = fill_value
    df.loc[df["NMHC(GT)"] == -200, "NMHC(GT)"] = 0
    return df

df = data_process(df)

# %%
missvalue_pre(df)
# Out:
# CO(GT)           0.189639
# PT08.S1(CO)      0.000000
# NMHC(GT)         0.000000
# C6H6(GT)         0.000000
# PT08.S2(NMHC)    0.000000
# NOx(GT)          0.188203
# PT08.S3(NOx)     0.000000
# NO2(GT)          0.188562
# PT08.S4(NO2)     0.000000
# PT08.S5(O3)      0.000000
# T                0.000000
# RH               0.000000
# AH               0.000000
# dtype: float64

# %% [markdown]
# #### obviously, NOX has strong correlation with NO2, so we can figure this out later.

# %% [markdown]
# ##### Create datasets for two tasks
# ##### delete all samples whose target are missing

# %%
df_preCO_train = df[df["CO(GT)"] != -200]
df_preNOx_train = df[df["NOx(GT)"] != - 200]
df_preCO_test = df[df["CO(GT)"] == -200].drop(["CO(GT)"], axis=1)
df_preNOx_test = df[df["NOx(GT)"] == -200].drop(["NOx(GT)"], axis=1)

# %%
missvalue_pre(df_preCO_train), missvalue_pre(df_preNOx_train)
# Out:
# CO(GT)           0.000000
# PT08.S1(CO)      0.000000
# NMHC(GT)         0.000000
# C6H6(GT)         0.000000
# PT08.S2(NMHC)    0.000000
# NOx(GT)          0.056696
# PT08.S3(NOx)     0.000000
# NO2(GT)          0.057139
# PT08.S4(NO2)     0.000000
# PT08.S5(O3)      0.000000
# T                0.000000
# RH               0.000000
# AH               0.000000
# dtype: float64
# CO(GT)           0.058364
# PT08.S1(CO)      0.000000
# NMHC(GT)         0.000000
# C6H6(GT)         0.000000
# PT08.S2(NMHC)    0.000000
# NOx(GT)          0.000000
# PT08.S3(NOx)     0.000000
# NO2(GT)          0.000442
# PT08.S4(NO2)     0.000000
# PT08.S5(O3)      0.000000
# T                0.000000
# RH               0.000000
# AH               0.000000
# dtype: float64
# (None, None)

# %% [markdown]
# #### Predicting CO content is a classification task

# %%
threshold = df_preCO_train["CO(GT)"].mean()
df_preCO_train["target"] = np.where(df_preCO_train["CO(GT)"] > threshold, 1, 0)
df_preCO_train.drop(["CO(GT)"], axis=1, inplace=True)
df_preNOx_train.rename(columns={"NOx(GT)":"target"}, inplace=True)
# Out:
# C:\Users\learn\AppData\Local\Temp\ipykernel_22760\1399961068.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_preCO_train["target"] = np.where(df_preCO_train["CO(GT)"] > threshold, 1, 0)
# C:\Users\learn\AppData\Local\Temp\ipykernel_22760\1399961068.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_preCO_train.drop(["CO(GT)"], axis=1, inplace=True)
# C:\Users\learn\AppData\Local\Temp\ipykernel_22760\1399961068.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_preNOx_train.rename(columns={"NOx(GT)":"target"}, inplace=True)

# %%
from sklearn.model_selection import train_test_split

y_preCO_target = df_preCO_train["target"]
df_preCO_train.drop(["target"], axis=1, inplace=True)
y_preNOx_target = df_preNOx_train["target"]
df_preNOx_train.drop(["target"], axis=1, inplace=True)
# Out:
# C:\Users\learn\AppData\Local\Temp\ipykernel_22760\102213358.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_preCO_train.drop(["target"], axis=1, inplace=True)
# C:\Users\learn\AppData\Local\Temp\ipykernel_22760\102213358.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_preNOx_train.drop(["target"], axis=1, inplace=True)

# %%
df_preCO_train.shape, y_preCO_target.shape, df_preNOx_train.shape, y_preNOx_target.shape
# Out:
# ((6773, 12), (6773,), (6785, 12), (6785,))

# %% [markdown]
# #### split the whole dataset into train and validaion to find the optimal parameters.

# %%
from sklearn.model_selection import train_test_split

X_preNOx, X_preNOx_valid, y_preNOX, y_preNOx_valid = train_test_split(df_preNOx_train, y_preNOx_target, random_state=42, shuffle=42, test_size=0.2)
X_preCO, X_preCO_valid, y_preCO, y_preCO_valid = train_test_split(df_preCO_train, y_preCO_target, random_state=42, shuffle=42, test_size=0.2)
# Out:
# C:\Users\learn\AppData\Roaming\Python\Python38\site-packages\sklearn\utils\_param_validation.py:594: FutureWarning: Passing an int for a boolean parameter is deprecated in version 1.2 and won't be supported anymore in version 1.4.
#   warnings.warn(

# %%
X_preNOx.shape, X_preNOx_valid.shape, y_preNOX.shape, y_preNOx_valid.shape
# Out:
# ((5428, 12), (1357, 12), (5428,), (1357,))

# %% [markdown]
# #### continue to fill in the two datasets, to satisfy the generalization ability, the missing value of the validaion should be filled with the data from the train dataset

# %%
fill_cols_CO = ["NOx(GT)", "NO2(GT)"]
fill_cols_NOx = ["CO(GT)", "NO2(GT)"]
for col in fill_cols_CO:
    fill_value = X_preCO.loc[X_preCO[col] >= 0, col].median()
    X_preCO.loc[X_preCO[col] < 0, col] = fill_value
    X_preCO_valid.loc[X_preCO_valid[col] < 0, col] = fill_value

for col in fill_cols_NOx:
    fill_value = X_preNOx.loc[X_preNOx[col] >= 0, col].median()
    X_preNOx.loc[X_preNOx[col] < 0, col] = fill_value
    X_preNOx_valid.loc[X_preNOx_valid[col] < 0, col] = fill_value

# %%
missvalue_pre(X_preNOx), missvalue_pre(X_preNOx_valid)
# Out:
# CO(GT)           0.0
# PT08.S1(CO)      0.0
# NMHC(GT)         0.0
# C6H6(GT)         0.0
# PT08.S2(NMHC)    0.0
# PT08.S3(NOx)     0.0
# NO2(GT)          0.0
# PT08.S4(NO2)     0.0
# PT08.S5(O3)      0.0
# T                0.0
# RH               0.0
# AH               0.0
# dtype: float64
# CO(GT)           0.0
# PT08.S1(CO)      0.0
# NMHC(GT)         0.0
# C6H6(GT)         0.0
# PT08.S2(NMHC)    0.0
# PT08.S3(NOx)     0.0
# NO2(GT)          0.0
# PT08.S4(NO2)     0.0
# PT08.S5(O3)      0.0
# T                0.0
# RH               0.0
# AH               0.0
# dtype: float64
# (None, None)

# %% [markdown]
# ##### Now the dataset has no missing value.

# %% [markdown]
# #### finding outliers and replacing them

# %%
plt.figure(figsize=(14, 8))
plt.subplot(1, 2, 1)
plt.boxplot(df_preCO_train.values, labels=df_preCO_train.columns)
plt.xticks(fontsize=10, rotation=45)
plt.subplot(1, 2, 2)
plt.boxplot(df_preNOx_train.values, labels=df_preNOx_train.columns)
plt.xticks(fontsize=10, rotation=45)
plt.show()

# %%
def findoutliners(X, sigma=3):
    outliners = []
    for col in X.columns:
        mean = np.mean(X[col])
        std = np.std(X[col])
        for i, val in enumerate(X[col]):
            if np.abs((val - mean) / std) > sigma:
                outliners.append((col, i, val))
    return outliners

def handle_outliers(df, target_col):
    df = df.reset_index(drop=True)
    outliers = findoutliners(df)
    # print("Outliers before handling:", outliers)
    for col, index, val in outliers:
        if col != target_col:
            mean = np.mean(df[col])
            df.at[index, col] = mean
    # outliers = findoutliners(df)
    # print("Outliers after handling:", outliers)

# %%
handle_outliers(X_preCO, "target")

handle_outliers(X_preNOx, "target")

# %%
plt.figure(figsize=(14, 8))
plt.subplot(1, 2, 1)
plt.boxplot(df_preCO_train.values, labels=df_preCO_train.columns)
plt.xticks(fontsize=10, rotation=45)
plt.subplot(1, 2, 2)
plt.boxplot(df_preNOx_train.values, labels=df_preNOx_train.columns)
plt.xticks(fontsize=10, rotation=45)
plt.show()

# %% [markdown]
# #### Next, it is necessary to perform consistency processing on the training and testing sets

# %% [markdown]
# ##### Standardized processing

# %%
X_totest_preNOx, X_totest_preCO = X_preCO.copy(), X_preNOx.copy()

# %%
from sklearn.preprocessing import MinMaxScaler

def minmax(df, df_test=None):
    feature_columns = df.columns
    minmaxscaler = MinMaxScaler()
    X = minmaxscaler.fit_transform(df)
    data = pd.DataFrame(X, columns=feature_columns)
    if not df_test.empty:
        df_test = minmaxscaler.transform(df_test)
        data_test = pd.DataFrame(df_test, columns=feature_columns)
    return data, data_test

X_preNOx, X_preNOx_valid = minmax(X_preNOx, X_preNOx_valid)
X_preCO, X_preCO_valid = minmax(X_preCO, X_preCO_valid)

# %%
X_preNOx.shape, X_preNOx_valid.shape, y_preNOX.shape, y_preNOx_valid.shape, X_preCO.shape, X_preCO_valid.shape, y_preCO.shape, y_preCO_valid.shape
# Out:
# ((5428, 12),
#  (1357, 12),
#  (5428,),
#  (1357,),
#  (5418, 12),
#  (1355, 12),
#  (5418,),
#  (1355,))

# %%
import seaborn as sns

# %%
def plot_kde(data):
    rows = 3
    cols = 4
    plt.figure(figsize=(12, 8))
    for i, col in enumerate(data.columns.tolist()):
        if col != "target":
            ax = plt.subplot(rows, cols, i + 1)
            ax = sns.kdeplot(data[col], color='r', fill=True)
            ax.set_xlabel(col)
            ax.set_ylabel("freq")
    plt.show()
    
plot_kde(X_preNOx)
plot_kde(X_preNOx_valid)

# %% [markdown]
# #### if we have the test dataset, we can find features by kde  with inconsistent distribution and then delete.

# %%
def plot_reg(data, target):
    rows = 4
    cols = 4
    plt.figure(figsize=(12, 10))
    for i, col in enumerate(data.columns.tolist()):
        ax = plt.subplot(rows, cols, i + 1)
        ax = sns.regplot(x=data[col], y=target, ax=ax, scatter_kws={'marker':'.', 's':3, 'alpha':0.3}, line_kws={'color':'k'})
        ax.set_xlabel(col)
        ax.set_ylabel("freq")
    plt.show()

plot_reg(X_preNOx, y_preNOX)

# %% [markdown]
# #### obviously, the NOX content has linear relationship with many features

# %% [markdown]
# ###### Regplot can be used to view the relationship between continuous and covariance matrices in regression tasks;
# ###### Viewing the Relationship between Regression Problems Using a Violin Chart

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.models import load_model
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, accuracy_score, mean_squared_error
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import EarlyStopping

# %% [markdown]
# ## the classification task

# %% [markdown]
# #### i try to use polynomialfeatures to create new features and find the more relationships than linear between features and labels

# %%
poly_class = PolynomialFeatures(degree=2)
X = poly_class.fit_transform(X_preCO)
X_valid = poly_class.transform(X_preCO_valid)
y = y_preCO.reset_index(drop=True)
y_valid = y_preCO_valid.reset_index(drop=True)

# %%
model_classification = Sequential()
# model.add(Dense(128, activation='relu', input_shape=(poly_X.shape[1],), kernel_regularizer=l2(0.01)))
model_classification.add(Dense(128, activation='relu', input_shape=(X.shape[1],), kernel_regularizer=l2(0.01)))
model_classification.add(Dropout(0.2))
model_classification.add(Dense(64, activation="relu", kernel_regularizer=l2(0.01)))
model_classification.add(Dropout(0.2))
model_classification.add(Dense(64, activation="relu", kernel_regularizer=l2(0.01)))
model_classification.add(Dropout(0.2))
model_classification.add(Dense(32, activation="relu", kernel_regularizer=l2(0.01)))
model_classification.add(Dropout(0.2))
# model.add(Dense(8, activation="relu", kernel_regularizer=l2(0.01)))
# model.add(Dropout(0.5))
model_classification.add(Dense(1, activation='sigmoid'))
early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=15,
    restore_best_weights=True
)
model_classification.compile(optimizer=Adam(), loss="binary_crossentropy", metrics=["accuracy"])
history = model_classification.fit(X, y, epochs=500, batch_size=128, validation_data=(X_valid, y_valid), callbacks=[early_stopping])
# Out:
# Epoch 1/500
# 43/43 [==============================] - 1s 5ms/step - loss: 2.8186 - accuracy: 0.6547 - val_loss: 1.9983 - val_accuracy: 0.8494
# Epoch 2/500
# 43/43 [==============================] - 0s 2ms/step - loss: 1.5106 - accuracy: 0.8739 - val_loss: 1.0793 - val_accuracy: 0.9166
# Epoch 3/500
# 43/43 [==============================] - 0s 2ms/step - loss: 0.9066 - accuracy: 0.9013 - val_loss: 0.7023 - val_accuracy: 0.9210
# Epoch 4/500
# 43/43 [==============================] - 0s 2ms/step - loss: 0.6308 - accuracy: 0.9055 - val_loss: 0.5174 - val_accuracy: 0.9232
# Epoch 5/500
# 43/43 [==============================] - 0s 2ms/step - loss: 0.4953 - accuracy: 0.9029 - val_loss: 0.4395 - val_accuracy: 0.9070
# Epoch 6/500
# 43/43 [==============================] - 0s 2ms/step - loss: 0.4183 - accuracy: 0.9168 - val_loss: 0.3730 - val_accuracy: 0.9203
# Epoch 7/500
# 43/43 [==============================] - 0s 2ms/step - loss: 0.3813 - accuracy: 0.9140 - val_loss: 0.3482 - val_accuracy: 0.9240
# Epoch 8/500
# 43/43 [==============================] - 0s 2ms/step - loss: 0.3615 - accuracy: 0.9147 - val_loss: 0.3306 - val_accuracy: 0.9181
# Epoch 9/500
# 43/43 [==============================] - 0s 2ms/step - loss: 0.3458 - accuracy: 0.9142 - val_loss: 0.3192 - val_accuracy: 0.9255
# Epoch 10/500
# 43/43 [==============================] - 0s 2ms/step - loss: 0.3387 - accuracy: 0.9145 - val_loss: 0.3116 - val_accuracy: 0.9284
# Epoch 11/500
# 43/43 [==============================] - 0s 2ms/step - loss: 0.3308 - accuracy: 0.9145 - val_loss: 0.3137 - val_accuracy: 0.9218
# Epoch 12/500
# 43/43 [==============================] - 0s 2ms/step - loss: 0.3253 - accuracy: 0.9157 - val_loss: 0.3071 - val_accuracy: 0.9225
# Epoch 13/500
# 43/43 [==============================] - 0s 2ms/step - loss: 0.3243 - accuracy: 0.9068 - val_loss: 0.3085 - val_accuracy: 0.9188
# Epoch 14/500
# 43/43 [==============================] - 0s 2ms/step - loss: 0.3210 - accuracy: 0.9094 - val_loss: 0.2957 - val_accuracy: 0.9232
# Epoch 15/500
# 43/43 [==============================] - 0s 2ms/step - loss: 0.3140 - accuracy: 0.9175 - val_loss: 0.2962 - val_accuracy: 0.9203
# Epoch 16/500
# 43/43 [==============================] - 0s 2ms/step - loss: 0.3138 - accuracy: 0.9149 - val_loss: 0.2944 - val_accuracy: 0.9218
# Epoch 17/500
# 43/43 [==============================] - 0s 2ms/step - loss: 0.3117 - accuracy: 0.9140 - val_loss: 0.2860 - val_accuracy: 0.9255
# Epoch 18/500
# 43/43 [==============================] - 0s 2ms/step - loss: 0.3096 - accuracy: 0.9142 - val_loss: 0.2836 - val_accuracy: 0.9255
# Epoch 19/500
# 43/43 [==============================] - 0s 2ms/step - loss: 0.3165 - accuracy: 0.9075 - val_loss: 0.2902 - val_accuracy: 0.9255
# Epoch 20/500
# 43/43 [==============================] - 0s 2ms/step - loss: 0.3097 - accuracy: 0.9120 - val_loss: 0.2829 - val_accuracy: 0.9292
# Epoch 21/500
# 43/43 [==============================] - 0s 2ms/step - loss: 0.3021 - accuracy: 0.9179 - val_loss: 0.2834 - val_accuracy: 0.9269
# Epoch 22/500
# 43/43 [==============================] - 0s 2ms/step - loss: 0.3026 - accuracy: 0.9158 - val_loss: 0.2820 - val_accuracy: 0.9255
# Epoch 23/500
# 43/43 [==============================] - 0s 2ms/step - loss: 0.3047 - accuracy: 0.9134 - val_loss: 0.2858 - val_accuracy: 0.9203
# Epoch 24/500
# 43/43 [==============================] - 0s 2ms/step - loss: 0.3008 - accuracy: 0.9105 - val_loss: 0.2887 - val_accuracy: 0.9203
# Epoch 25/500
# 43/43 [==============================] - 0s 2ms/step - loss: 0.2999 - accuracy: 0.9155 - val_loss: 0.2769 - val_accuracy: 0.9277
# Epoch 26/500
# 43/43 [==============================] - 0s 2ms/step - loss: 0.2962 - accuracy: 0.9157 - val_loss: 0.2768 - val_accuracy: 0.9269
# Epoch 27/500
# 43/43 [==============================] - 0s 2ms/step - loss: 0.2966 - accuracy: 0.9140 - val_loss: 0.2935 - val_accuracy: 0.9144
# Epoch 28/500
# 43/43 [==============================] - 0s 2ms/step - loss: 0.3040 - accuracy: 0.9103 - val_loss: 0.2750 - val_accuracy: 0.9269
# Epoch 29/500
# 43/43 [==============================] - 0s 2ms/step - loss: 0.2931 - accuracy: 0.9168 - val_loss: 0.2841 - val_accuracy: 0.9210
# Epoch 30/500
# 43/43 [==============================] - 0s 2ms/step - loss: 0.2997 - accuracy: 0.9140 - val_loss: 0.2718 - val_accuracy: 0.9262
# Epoch 31/500
# 43/43 [==============================] - 0s 2ms/step - loss: 0.2953 - accuracy: 0.9164 - val_loss: 0.2698 - val_accuracy: 0.9277
# Epoch 32/500
# 43/43 [==============================] - 0s 2ms/step - loss: 0.2975 - accuracy: 0.9114 - val_loss: 0.2752 - val_accuracy: 0.9225
# Epoch 33/500
# 43/43 [==============================] - 0s 2ms/step - loss: 0.2936 - accuracy: 0.9155 - val_loss: 0.2699 - val_accuracy: 0.9284
# Epoch 34/500
# 43/43 [==============================] - 0s 2ms/step - loss: 0.2912 - accuracy: 0.9199 - val_loss: 0.2685 - val_accuracy: 0.9247
# Epoch 35/500
# 43/43 [==============================] - 0s 2ms/step - loss: 0.
500
# 43/43 [==============================] - 0s 2ms/step - loss: 0.2660 - accuracy: 0.9140 - val_loss: 0.2471 - val_accuracy: 0.9255
# Epoch 217/500
# 43/43 [==============================] - 0s 2ms/step - loss: 0.2586 - accuracy: 0.9210 - val_loss: 0.2507 - val_accuracy: 0.9247
# Epoch 218/500
# 43/43 [==============================] - 0s 2ms/step - loss: 0.2626 - accuracy: 0.9182 - val_loss: 0.2459 - val_accuracy: 0.9292
# Epoch 219/500
# 43/43 [==============================] - 0s 2ms/step - loss: 0.2615 - accuracy: 0.9157 - val_loss: 0.2391 - val_accuracy: 0.9306
# Epoch 220/500
# 43/43 [==============================] - 0s 2ms/step - loss: 0.2611 - accuracy: 0.9197 - val_loss: 0.2387 - val_accuracy: 0.9284
# Epoch 221/500
# 43/43 [==============================] - 0s 2ms/step - loss: 0.2644 - accuracy: 0.9166 - val_loss: 0.2401 - val_accuracy: 0.9284
# Epoch 222/500
# 43/43 [==============================] - 0s 2ms/step - loss: 0.2662 - accuracy: 0.9140 - val_loss: 0.2439 - val_accuracy: 0.9269
# Epoch 223/500
# 43/43 [==============================] - 0s 2ms/step - loss: 0.2718 - accuracy: 0.9133 - val_loss: 0.2456 - val_accuracy: 0.9269
# Epoch 224/500
# 43/43 [==============================] - 0s 2ms/step - loss: 0.2598 - accuracy: 0.9192 - val_loss: 0.2397 - val_accuracy: 0.9292
# Epoch 225/500
# 43/43 [==============================] - 0s 2ms/step - loss: 0.2631 - accuracy: 0.9193 - val_loss: 0.2523 - val_accuracy: 0.9218
# Epoch 226/500
# 43/43 [==============================] - 0s 2ms/step - loss: 0.2642 - accuracy: 0.9181 - val_loss: 0.2635 - val_accuracy: 0.9159
# Epoch 227/500
# 43/43 [==============================] - 0s 2ms/step - loss: 0.2639 - accuracy: 0.9181 - val_loss: 0.2459 - val_accuracy: 0.9255
# Epoch 228/500
# 43/43 [==============================] - 0s 2ms/step - loss: 0.2626 - accuracy: 0.9164 - val_loss: 0.2435 - val_accuracy: 0.9255
# Epoch 229/500
# 43/43 [==============================] - 0s 3ms/step - loss: 0.2593 - accuracy: 0.9225 - val_loss: 0.2383 - val_accuracy: 0.9277
# Epoch 230/500
# 43/43 [==============================] - 0s 2ms/step - loss: 0.2617 - accuracy: 0.9171 - val_loss: 0.2450 - val_accuracy: 0.9299

# %%
plt.figure(figsize=(15, 8))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='train_acc')
plt.plot(history.history['val_accuracy'], label='val_acc')
plt.xlabel('Epochs')
plt.ylabel('accuracy')
plt.legend()
plt.show()

# %%
predict = (model_classification.predict(X_valid) > 0.5).astype('int')
accuracy_score(y_valid.values, predict)
# Out:
# 43/43 [==============================] - 0s 753us/step
# 0.9276752767527675

# %%
from sklearn.metrics import confusion_matrix

# %%
cm = confusion_matrix(y_valid, predict)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Predicted 0', 'Predicted 1'], yticklabels=['True 0', 'True 1'])
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()

# %%
from sklearn.metrics import accuracy_score, precision_score

accuracy = accuracy_score(predict, y_valid)
precision = precision_score(predict, y_valid)
print("                       | Accuracy  | Precision | Number_of_samples")
print(f'CO(GT) classification  |  {accuracy:.4f}   |  {precision:.4f}   |    {len(y_preCO_valid)}')
# Out:
#                        | Accuracy  | Precision | Number_of_samples
# CO(GT) classification  |  0.9277   |  0.9007   |    1355

# %%
# for row in cm:
#     print(" ".join(str(x) for x in row))

# %%
model_classification.save("classification_model.h5")
# Out:
# c:\ProgramData\anaconda3\envs\tensorflow\lib\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# ## Regression Task

# %%
poly_reg = PolynomialFeatures(degree=2)
X = poly_reg.fit_transform(X_preNOx)
X_valid = poly_reg.transform(X_preNOx_valid)
y = y_preNOX.reset_index(drop=True)
y_valid = y_preNOx_valid.reset_index(drop=True)

# %%
model_regression = Sequential()

model_regression.add(Dense(256, activation='relu', input_shape=(X.shape[1],), kernel_regularizer=l2(0.01)))
# model_regression.add(Dropout(0.2))
model_regression.add(Dense(128, activation='relu', kernel_regularizer=l2(0.01)))
# model_regression.add(Dropout(0.2))
model_regression.add(Dense(64, activation='relu', kernel_regularizer=l2(0.01)))
# model_regression.add(Dropout(0.2))
model_regression.add(Dense(32, activation='relu', kernel_regularizer=l2(0.01)))
# model_regression.add(Dropout(0.2))
model_regression.add(Dense(16, activation='relu', kernel_regularizer=l2(0.01)))
# model_regression.add(Dropout(0.2))
model_regression.add(Dense(1))
early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=15,
    restore_best_weights=True
)
model_regression.compile(optimizer=Adam(), loss='mean_squared_error', metrics=['mean_absolute_error'])
history = model_regression.fit(X, y, epochs=500, batch_size=64, validation_data=(X_valid, y_valid), callbacks=[early_stopping])
# Out:
# Epoch 1/500
# 85/85 [==============================] - 1s 4ms/step - loss: 69612.0469 - mean_absolute_error: 187.1323 - val_loss: 22653.0000 - val_mean_absolute_error: 115.4758
# Epoch 2/500
# 85/85 [==============================] - 0s 1ms/step - loss: 15243.9795 - mean_absolute_error: 89.3634 - val_loss: 9076.3584 - val_mean_absolute_error: 60.0775
# Epoch 3/500
# 85/85 [==============================] - 0s 2ms/step - loss: 7801.1362 - mean_absolute_error: 57.5176 - val_loss: 7591.2949 - val_mean_absolute_error: 55.5177
# Epoch 4/500
# 85/85 [==============================] - 0s 1ms/step - loss: 6950.7993 - mean_absolute_error: 54.4579 - val_loss: 6919.0420 - val_mean_absolute_error: 52.7177
# Epoch 5/500
# 85/85 [==============================] - 0s 1ms/step - loss: 6250.7642 - mean_absolute_error: 51.5329 - val_loss: 6346.0679 - val_mean_absolute_error: 51.4461
# Epoch 6/500
# 85/85 [==============================] - 0s 1ms/step - loss: 5798.0513 - mean_absolute_error: 49.2862 - val_loss: 5799.9434 - val_mean_absolute_error: 47.6860
# Epoch 7/500
# 85/85 [==============================] - 0s 1ms/step - loss: 5325.3521 - mean_absolute_error: 46.9235 - val_loss: 5519.7383 - val_mean_absolute_error: 47.6164
# Epoch 8/500
# 85/85 [==============================] - 0s 1ms/step - loss: 5071.6509 - mean_absolute_error: 46.0622 - val_loss: 5245.9775 - val_mean_absolute_error: 45.9470
# Epoch 9/500
# 85/85 [==============================] - 0s 1ms/step - loss: 4816.5698 - mean_absolute_error: 44.8195 - val_loss: 5072.8267 - val_mean_absolute_error: 44.0270
# Epoch 10/500
# 85/85 [==============================] - 0s 1ms/step - loss: 4605.4756 - mean_absolute_error: 43.9251 - val_loss: 5341.3789 - val_mean_absolute_error: 48.0652
# Epoch 11/500
# 85/85 [==============================] - 0s 1ms/step - loss: 4544.2065 - mean_absolute_error: 43.6106 - val_loss: 5100.8159 - val_mean_absolute_error: 42.9875
# Epoch 12/500
# 85/85 [==============================] - 0s 1ms/step - loss: 4486.0537 - mean_absolute_error: 43.2179 - val_loss: 5411.1851 - val_mean_absolute_error: 44.3430
# Epoch 13/500
# 85/85 [==============================] - 0s 1ms/step - loss: 4366.1938 - mean_absolute_error: 42.7422 - val_loss: 4765.2021 - val_mean_absolute_error: 44.2822
# Epoch 14/500
# 85/85 [==============================] - 0s 1ms/step - loss: 4305.3223 - mean_absolute_error: 42.2035 - val_loss: 4688.5576 - val_mean_absolute_error: 41.8990
# Epoch 15/500
# 85/85 [==============================] - 0s 1ms/step - loss: 4217.0908 - mean_absolute_error: 41.9598 - val_loss: 4464.1206 - val_mean_absolute_error: 42.2703
# Epoch 16/500
# 85/85 [==============================] - 0s 1ms/step - loss: 4091.3203 - mean_absolute_error: 40.8042 - val_loss: 4434.5464 - val_mean_absolute_error: 42.8077
# Epoch 17/500
# 85/85 [==============================] - 0s 1ms/step - loss: 4007.2451 - mean_absolute_error: 40.5015 - val_loss: 4334.7168 - val_mean_absolute_error: 41.1046
# Epoch 18/500
# 85/85 [==============================] - 0s 1ms/step - loss: 4001.4189 - mean_absolute_error: 40.2685 - val_loss: 4183.7812 - val_mean_absolute_error: 40.0943
# Epoch 19/500
# 85/85 [==============================] - 0s 1ms/step - loss: 3935.5830 - mean_absolute_error: 39.9102 - val_loss: 4439.4595 - val_mean_absolute_error: 39.6281
# Epoch 20/500
# 85/85 [==============================] - 0s 1ms/step - loss: 3821.3198 - mean_absolute_error: 38.9920 - val_loss: 4154.5947 - val_mean_absolute_error: 40.7440
# Epoch 21/500
# 85/85 [==============================] - 0s 1ms/step - loss: 3798.6467 - mean_absolute_error: 39.3298 - val_loss: 4261.1543 - val_mean_absolute_error: 39.5832
# Epoch 22/500
# 85/85 [==============================] - 0s 1ms/step - loss: 3707.5059 - mean_absolute_error: 38.5315 - val_loss: 3999.3328 - val_mean_absolute_error: 39.7196
# Epoch 23/500
# 85/85 [==============================] - 0s 1ms/step - loss: 3874.7229 - mean_absolute_error: 39.3579 - val_loss: 3957.3164 - val_mean_absolute_error: 37.7766
# Epoch 24/500
# 85/85 [==============================] - 0s 1ms/step - loss: 3626.8750 - mean_absolute_error: 37.9694 - val_loss: 3851.0056 - val_mean_absolute_error: 38.3488
# Epoch 25/500
# 85/85 [==============================] - 0s 1ms/step - loss: 3610.1919 - mean_absolute_error: 37.6398 - val_loss: 3856.4495 - val_mean_absolute_error: 37.8275
# Epoch 26/500
# 85/85 [==============================] - 0s 1ms/step - loss: 3510.5461 - mean_absolute_error: 37.1633 - val_loss: 3861.2458 - val_mean_absolute_error: 37.4911
# Epoch 27/500
# 85/85 [==============================] - 0s 1ms/step - loss: 3599.6956 - mean_absolute_error: 37.2097 - val_loss: 3747.8577 - val_mean_absolute_error: 37.0629
# Epoch 28/500
# 85/85 [==============================] - 0s 1ms/step - loss: 3626.0439 - mean_absolute_error: 37.3969 - val_loss: 3736.0557 - val_mean_absolute_error: 36.9919
# Epoch 29/500
# 85/85 [==============================] - 0s 1ms/step - loss: 3558.0447 - mean_absolute_error: 37.3617 - val_loss: 3614.6960 - val_mean_absolute_error: 36.8925
# Epoch 30/500
# 85/85 [==============================] - 0s 1ms/step - loss: 3464.0991 - mean_absolute_error: 36.7048 - val_loss: 3563.8835 - val_mean_absolute_error: 36.3857
# Epoch 31/500
# 85/85 [==============================] - 0s 1ms/step - loss: 3431.1953 - mean_absolute_error: 36.4338 - val_loss: 3563.2314 - val_mean_absolute_error: 36.0035
# Epoch 32/500
# 85/85 [==============================] - 0s 1ms/step - loss: 3531.7227 - mean_absolute_error: 36.9479 - val_loss: 3792.8413 - val_mean_absolute_error: 39.7437
# Epoch 33/500
# 85/85 [==============================] - 0s 1ms/step - loss: 3435.4226 - mean_absolute_error: 36.1846 - val_loss: 3510.9009 - val_mean_absolute_error: 36.5501
# Epoch 34/500
# 85/85 [==============================] - 0s 1ms/step - loss: 3339.9607 - mean_absolute_error: 36.1625 - val_loss: 3639.6091 - val_mean_absolute_error: 35.7895
# Epoch 35/500
# 85/85 [==============================] - 0s 1ms/step - loss: 3360.2510 - mean_absolute_error: 35.8578 - val_loss: 3579.2705 - val_mean_absolute_error: 36.3360
# Epoch 36/500
# 85/85 [==============================] - 0s 2ms/step - loss: 3623.2578 - mean_absolute_error: 37.8175 - val_loss: 3413.5808 - val_mean_absolute_error: 36.1058
# Epoch 37/500
# 85/85 [==============================] - 0s 1ms/step - loss: 3349.0588 - mean_absolute_error: 36.1664 - val_loss: 3774.1318 - val_mean_absolute_error: 40.0653
# Epoch 38/500
# 85/85 [==============================] - 0s 1ms/step - loss: 3363.0776 - mean_absolute_error: 36.2208 - val_loss: 4042.1663 - val_mean_absolute_error: 41.3315
# Epoch 39/500
# 85/85 [==============================] - 0s 1ms/step - loss: 3287.1470 - mean_absolute_error: 35.3842 - val_loss: 3339.6765 - val_mean_absolute_error: 35.4706
# Epoch 40/500
# 85/85 [==============================] - 0s 1ms/step - loss: 3327.4834 - mean_absolute_error: 35.7975 - val_loss: 3382.9609 - val_mean_absolute_error: 35.1161
# Epoch 41/500
# 85/85 [==============================] - 0s 1ms/step - loss: 3217.3276 - mean_absolute_error: 35.0564 - val_loss: 3359.1272 - val_mean_absolute_error: 34.8307
# Epoch 42/500
# 85/85 [==============================] - 0s 1ms/step - loss: 3196.5784 - mean_absolute_error: 35.1269 - val_loss: 3388.9907 - val_mean_absolute_error: 34.9222
# Epoch 43/500
# 85/85 [==============================] - 0s 1ms/step - loss: 3154.1824 - mean_absolute_error: 34.9099 - val_loss: 3239.4326 - val_mean_absolute_error: 34.8139
# Epoch 44/500
# 85/85 [==============================] - 0s 1ms/step - loss: 3267.7383 - mean_absolute_error: 35.4929 - val_loss: 3230.5371 - val_mean_absolute_error: 34.9357
# Epoch 45/500
# 85/85 [==============================] - 0s 1ms/step - loss: 3157.6604 - mean_absolute_error: 35.2653 - val_loss: 4269.3350 - val_mean_absolute_error: 39.5658
# Epoch 46/500
# 85/85 [==============================] - 0s 1ms/step - loss: 3275.3113 - mean_absolute_error: 35.3909 - val_loss: 3281.6245 - val_mean_absolute_error: 34.2494
# Epoch 47/500
# 85/85 [==============================] - 0s 1ms/step - loss: 3083.8665 - mean_absolute_error: 34.4747 - val_loss: 3195.4514 - val_mean_absolute_error: 35.4002
# Epoch 48/500
# 85/85 [==============================] - 0s 1ms/step - loss: 3079.0205 - mean_absolute_error: 34.3576 - val_loss: 3230.6304 - val_mean_absolute_error: 36.0997
# Epoch 49/500
# 85/85 [==============================] - 0s 1ms/step - loss: 3188.9268 - mean_absolute_error: 35.0813 - val_loss: 3281.6482 - val_mean_absolute_error: 34.4810
# Epoch 50/500
# 85/85 [==============================] - 0s 1ms/step - loss: 3057.9846 - mean_absolute_error: 34.5425 - val_loss: 3131.5552 - val_mean_absolute_error: 35.0889
# Epoch 51/500
# 85/85 [==============================] - 0s 1ms/step - loss: 3030.5808 - mean_absolute_error: 34.3548 - val_loss: 3153.1243 - val_mean_absolute_error: 35.5024
# Epoch 52/500
# 85/85 [==============================] - 0s 1ms/step - loss: 3067.8804 - mean_absolute_error: 34.4646 - val_loss: 3184.4609 - val_mean_absolute_error: 34.4923
# Epoch 53/500
# 85/85 [==============================] - 0s 1ms/step - loss: 3024.6995 - mean_absolute_error: 34.1662 - val_loss: 3048.9126 - val_mean_absolute_error: 34.0675
# Epoch 54/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2941.9048 - mean_absolute_error: 33.8359 - val_loss: 3301.8892 - val_mean_absolute_error: 34.2166
# Epoch 55/500
# 85/85 [==============================] - 0s 1ms/step - loss: 3015.1526 - mean_absolute_error: 34.1733 - val_loss: 3177.7019 - val_mean_absolute_error: 33.7596
# Epoch 56/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2921.4163 - mean_absolute_error: 33.6571 - val_loss: 3012.0781 - val_mean_absolute_error: 33.4249
# Epoch 57/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2975.1335 - mean_absolute_error: 33.8043 - val_loss: 3582.0823 - val_mean_absolute_error: 40.2244
# Epoch 58/500
# 85/85 [==============================] - 0s 1ms/step - loss: 3013.8816 - mean_absolute_error: 34.2813 - val_loss: 3251.6584 - val_mean_absolute_error: 36.9203
# Epoch 59/500
# 85/85 [==============================] - 0s 1ms/step - loss: 3168.3081 - mean_absolute_error: 35.2509 - val_loss: 3329.5107 - val_mean_absolute_error: 38.1022
# Epoch 60/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2922.4917 - mean_absolute_error: 33.7234 - val_loss: 2910.7288 - val_mean_absolute_error: 33.0713
# Epoch 61/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2824.0762 - mean_absolute_error: 33.0209 - val_loss: 2923.8428 - val_mean_absolute_error: 33.5649
# Epoch 62/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2837.6287 - mean_absolute_error: 33.2272 - val_loss: 2892.9746 - val_mean_absolute_error: 33.1747
# Epoch 63/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2879.7769 - mean_absolute_error: 33.2795 - val_loss: 2873.7380 - val_mean_absolute_error: 33.2910
# Epoch 64/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2784.0859 - mean_absolute_error: 32.7022 - val_loss: 2873.1318 - val_mean_absolute_error: 32.4150
# Epoch 65/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2838.7134 - mean_absolute_error: 33.3637 - val_loss: 2832.5808 - val_mean_absolute_error: 32.9524
# Epoch 66/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2778.5466 - mean_absolute_error: 32.6145 - val_loss: 2944.7014 - val_mean_absolute_error: 32.9112
# Epoch 67/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2860.8713 - mean_absolute_error: 33.3956 - val_loss: 2864.7751 - val_mean_absolute_error: 32.6369
# Epoch 68/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2799.0183 - mean_absolute_error: 33.0840 - val_loss: 2901.9724 - val_mean_absolute_error: 34.3375
# Epoch 69/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2751.9380 - mean_absolute_error: 32.6877 - val_loss: 2822.1909 - val_mean_absolute_error: 33.1889
# Epoch 70/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2983.6584 - mean_absolute_error: 34.0224 - val_loss: 2758.5027 - val_mean_absolute_error: 32.5022
# Epoch 71/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2772.7651 - mean_absolute_error: 32.7216 - val_loss: 2854.1506 - val_mean_absolute_error: 32.3420
# Epoch 72/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2758.8340 - mean_absolute_error: 32.4942 - val_loss: 2851.3965 - val_mean_absolute_error: 33.6107
# Epoch 73/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2726.8396 - mean_absolute_error: 32.7382 - val_loss: 2784.8232 - val_mean_absolute_error: 32.7559
# Epoch 74/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2744.6418 - mean_absolute_error: 32.2369 - val_loss: 2838.8142 - val_mean_absolute_error: 32.1559
# Epoch 75/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2838.9492 - mean_absolute_error: 33.1741 - val_loss: 2703.6978 - val_mean_absolute_error: 31.8678
# Epoch 76/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2706.4509 - mean_absolute_error: 32.4355 - val_loss: 3695.7061 - val_mean_absolute_error: 40.6050
# Epoch 77/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2875.7708 - mean_absolute_error: 33.7264 - val_loss: 3252.2227 - val_mean_absolute_error: 37.0752
# Epoch 78/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2741.7903 - mean_absolute_error: 33.1207 - val_loss: 2856.0146 - val_mean_absolute_error: 31.8238
# Epoch 79/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2658.2480 - mean_absolute_error: 31.9546 - val_loss: 2675.6995 - val_mean_absolute_error: 32.0193
# Epoch 80/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2701.0549 - mean_absolute_error: 32.2687 - val_loss: 2646.1392 - val_mean_absolute_error: 31.3862
# Epoch 81/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2630.6626 - mean_absolute_error: 31.6959 - val_loss: 2730.8230 - val_mean_absolute_error: 32.1657
# Epoch 82/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2601.7258 - mean_absolute_error: 31.4466 - val_loss: 2744.1438 - val_mean_absolute_error: 32.7160
# Epoch 83/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2679.3149 - mean_absolute_error: 32.1831 - val_loss: 3077.4756 - val_mean_absolute_error: 32.7630
# Epoch 84/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2710.8052 - mean_absolute_error: 32.3914 - val_loss: 2700.2769 - val_mean_absolute_error: 31.5344
# Epoch 85/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2610.6914 - mean_absolute_error: 31.5034 - val_loss: 2962.1938 - val_mean_absolute_error: 35.9963
# Epoch 86/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2595.6797 - mean_absolute_error: 31.4935 - val_loss: 2696.6941 - val_mean_absolute_error: 31.8988
# Epoch 87/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2639.6543 - mean_absolute_error: 31.8870 - val_loss: 2718.1548 - val_mean_absolute_error: 31.6429
# Epoch 88/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2627.0208 - mean_absolute_error: 31.7314 - val_loss: 2881.6436 - val_mean_absolute_error: 35.1124
# Epoch 89/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2630.2986 - mean_absolute_error: 31.9499 - val_loss: 2589.1118 - val_mean_absolute_error: 31.2158
# Epoch 90/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2612.5378 - mean_absolute_error: 31.5590 - val_loss: 2564.5859 - val_mean_absolute_error: 30.8035
# Epoch 91/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2575.7917 - mean_absolute_error: 31.5895 - val_loss: 2533.1580 - val_mean_absolute_error: 30.7627
# Epoch 92/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2604.2642 - mean_absolute_error: 31.7311 - val_loss: 2792.0703 - val_mean_absolute_error: 33.7419
# Epoch 93/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2836.5881 - mean_absolute_error: 33.3846 - val_loss: 2940.4089 - val_mean_absolute_error: 36.7229
# Epoch 94/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2604.8757 - mean_absolute_error: 31.7362 - val_loss: 2623.0776 - val_mean_absolute_error: 31.9736
# Epoch 95/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2658.8677 - mean_absolute_error: 31.9188 - val_loss: 2927.3269 - val_mean_absolute_error: 36.1471
# Epoch 96/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2710.2805 - mean_absolute_error: 32.4618 - val_loss: 2549.7432 - val_mean_absolute_error: 30.6108
# Epoch 97/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2524.4055 - mean_absolute_error: 31.2113 - val_loss: 2586.6833 - val_mean_absolute_error: 31.0284
# Epoch 98/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2625.7334 - mean_absolute_error: 31.7391 - val_loss: 2534.8240 - val_mean_absolute_error: 30.9777
# Epoch 99/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2556.2834 - mean_absolute_error: 31.2506 - val_loss: 2559.2263 - val_mean_absolute_error: 31.0902
# Epoch 100/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2595.3630 - mean_absolute_error: 31.4347 - val_loss: 2547.4846 - val_mean_absolute_error: 30.9985
# Epoch 101/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2572.0891 - mean_absolute_error: 31.0964 - val_loss: 2474.0818 - val_mean_absolute_error: 30.8395
# Epoch 102/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2598.0706 - mean_absolute_error: 31.3412 - val_loss: 2575.1780 - val_mean_absolute_error: 31.9288
# Epoch 103/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2609.5525 - mean_absolute_error: 31.5177 - val_loss: 2411.7083 - val_mean_absolute_error: 30.1705
# Epoch 104/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2507.0942 - mean_absolute_error: 30.6374 - val_loss: 2775.3879 - val_mean_absolute_error: 33.4391
# Epoch 105/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2605.8982 - mean_absolute_error: 31.8326 - val_loss: 2503.1655 - val_mean_absolute_error: 31.3318
# Epoch 106/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2638.7029 - mean_absolute_error: 31.5167 - val_loss: 2771.9285 - val_mean_absolute_error: 33.2323
# Epoch 107/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2488.3567 - mean_absolute_error: 30.7592 - val_loss: 2758.6846 - val_mean_absolute_error: 31.9880
# Epoch 108/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2582.0000 - mean_absolute_error: 31.5105 - val_loss: 2505.1172 - val_mean_absolute_error: 31.1231
# Epoch 109/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2466.1011 - mean_absolute_error: 30.7024 - val_loss: 2461.9304 - val_mean_absolute_error: 30.6875
# Epoch 110/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2520.3428 - mean_absolute_error: 31.1113 - val_loss: 2442.5642 - val_mean_absolute_error: 30.0191
# Epoch 111/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2482.1235 - mean_absolute_error: 30.5369 - val_loss: 2439.7131 - val_mean_absolute_error: 30.8490
# Epoch 112/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2457.3188 - mean_absolute_error: 30.3925 - val_loss: 2660.1846 - val_mean_absolute_error: 33.2436
# Epoch 113/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2521.8599 - mean_absolute_error: 30.9006 - val_loss: 2382.8374 - val_mean_absolute_error: 30.3593
# Epoch 114/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2487.5061 - mean_absolute_error: 30.8045 - val_loss: 2815.8684 - val_mean_absolute_error: 35.2539
# Epoch 115/500
# 85/85 [==============================] - 0s 2ms/step - loss: 2532.2847 - mean_absolute_error: 31.1570 - val_loss: 2466.6326 - val_mean_absolute_error: 31.1296
# Epoch 116/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2577.3604 - mean_absolute_error: 31.3743 - val_loss: 3025.0188 - val_mean_absolute_error: 37.3615
# Epoch 117/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2494.4031 - mean_absolute_error: 31.0680 - val_loss: 2456.8540 - val_mean_absolute_error: 30.4877
# Epoch 118/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2504.4712 - mean_absolute_error: 31.1105 - val_loss: 2934.0762 - val_mean_absolute_error: 33.0152
# Epoch 119/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2567.0769 - mean_absolute_error: 31.1245 - val_loss: 2509.8113 - val_mean_absolute_error: 31.3836
# Epoch 120/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2532.9187 - mean_absolute_error: 31.1790 - val_loss: 2798.3220 - val_mean_absolute_error: 33.6412
# Epoch 121/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2475.5107 - mean_absolute_error: 30.8604 - val_loss: 2461.8525 - val_mean_absolute_error: 30.7344
# Epoch 122/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2513.3313 - mean_absolute_error: 31.5087 - val_loss: 2681.5291 - val_mean_absolute_error: 31.1389
# Epoch 123/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2539.4983 - mean_absolute_error: 31.3963 - val_loss: 2370.2156 - val_mean_absolute_error: 30.3240
# Epoch 124/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2483.1287 - mean_absolute_error: 30.8954 - val_loss: 2463.2368 - val_mean_absolute_error: 30.1754
# Epoch 125/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2493.3806 - mean_absolute_error: 30.7815 - val_loss: 2341.3638 - val_mean_absolute_error: 29.5306
# Epoch 126/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2440.0303 - mean_absolute_error: 30.4088 - val_loss: 2533.4688 - val_mean_absolute_error: 30.7333
# Epoch 127/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2546.0806 - mean_absolute_error: 30.8961 - val_loss: 2419.5647 - val_mean_absolute_error: 29.8883
# Epoch 128/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2460.4917 - mean_absolute_error: 30.6596 - val_loss: 2995.0378 - val_mean_absolute_error: 34.1941
# Epoch 129/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2471.2961 - mean_absolute_error: 30.8831 - val_loss: 2351.4009 - val_mean_absolute_error: 29.6642
# Epoch 130/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2538.8843 - mean_absolute_error: 30.9488 - val_loss: 2526.9788 - val_mean_absolute_error: 32.4980
# Epoch 131/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2485.1667 - mean_absolute_error: 30.5303 - val_loss: 2602.9866 - val_mean_absolute_error: 30.8856
# Epoch 132/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2515.7183 - mean_absolute_error: 30.9951 - val_loss: 2340.2759 - val_mean_absolute_error: 29.9176
# Epoch 133/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2393.7593 - mean_absolute_error: 30.0001 - val_loss: 2534.1848 - val_mean_absolute_error: 31.4888
# Epoch 134/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2373.4968 - mean_absolute_error: 29.9521 - val_loss: 2356.2910 - val_mean_absolute_error: 30.0854
# Epoch 135/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2465.3115 - mean_absolute_error: 30.5715 - val_loss: 2427.4023 - val_mean_absolute_error: 31.0066
# Epoch 136/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2536.8811 - mean_absolute_error: 31.2031 - val_loss: 2369.8938 - val_mean_absolute_error: 30.3086
# Epoch 137/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2435.6560 - mean_absolute_error: 30.1538 - val_loss: 2570.4485 - val_mean_absolute_error: 30.9631
# Epoch 138/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2427.7505 - mean_absolute_error: 30.2326 - val_loss: 2470.4937 - val_mean_absolute_error: 30.0576
# Epoch 139/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2413.6235 - mean_absolute_error: 30.0641 - val_loss: 2481.8240 - val_mean_absolute_error: 31.4478
# Epoch 140/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2457.9817 - mean_absolute_error: 30.3037 - val_loss: 2388.9717 - val_mean_absolute_error: 30.7824
# Epoch 141/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2471.6357 - mean_absolute_error: 30.4972 - val_loss: 2398.3247 - val_mean_absolute_error: 31.1632
# Epoch 142/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2415.9949 - mean_absolute_error: 30.4262 - val_loss: 2362.4692 - val_mean_absolute_error: 30.4193
# Epoch 143/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2479.2300 - mean_absolute_error: 30.5274 - val_loss: 2325.2078 - val_mean_absolute_error: 29.3185
# Epoch 144/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2379.1687 - mean_absolute_error: 29.9750 - val_loss: 2294.3076 - val_mean_absolute_error: 29.4057
# Epoch 145/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2453.6042 - mean_absolute_error: 30.4126 - val_loss: 2793.4102 - val_mean_absolute_error: 31.6536
# Epoch 146/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2397.6245 - mean_absolute_error: 30.0130 - val_loss: 2429.7390 - val_mean_absolute_error: 32.3072
# Epoch 147/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2395.5591 - mean_absolute_error: 30.1774 - val_loss: 2376.7893 - val_mean_absolute_error: 30.5289
# Epoch 148/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2367.5288 - mean_absolute_error: 29.6542 - val_loss: 2292.6389 - val_mean_absolute_error: 29.2446
# Epoch 149/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2356.4192 - mean_absolute_error: 29.6750 - val_loss: 2443.5071 - val_mean_absolute_error: 30.0201
# Epoch 150/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2579.2876 - mean_absolute_error: 31.4389 - val_loss: 2292.4514 - val_mean_absolute_error: 29.5086
# Epoch 151/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2357.5520 - mean_absolute_error: 29.8702 - val_loss: 2275.9290 - val_mean_absolute_error: 29.3571
# Epoch 152/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2355.7407 - mean_absolute_error: 29.9486 - val_loss: 2285.1392 - val_mean_absolute_error: 29.3317
# Epoch 153/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2390.8748 - mean_absolute_error: 30.2942 - val_loss: 2489.9258 - val_mean_absolute_error: 32.3507
# Epoch 154/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2415.5068 - mean_absolute_error: 30.2268 - val_loss: 2363.0515 - val_mean_absolute_error: 30.1152
# Epoch 155/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2383.6135 - mean_absolute_error: 30.0152 - val_loss: 2456.4995 - val_mean_absolute_error: 29.7572
# Epoch 156/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2353.0928 - mean_absolute_error: 29.8807 - val_loss: 2279.8870 - val_mean_absolute_error: 29.4461
# Epoch 157/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2388.9541 - mean_absolute_error: 30.1263 - val_loss: 2989.5403 - val_mean_absolute_error: 35.0385
# Epoch 158/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2333.8125 - mean_absolute_error: 29.7658 - val_loss: 2490.9807 - val_mean_absolute_error: 30.8862
# Epoch 159/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2368.2893 - mean_absolute_error: 29.8718 - val_loss: 2334.8103 - val_mean_absolute_error: 29.6693
# Epoch 160/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2394.4961 - mean_absolute_error: 30.0790 - val_loss: 2352.9805 - val_mean_absolute_error: 30.0598
# Epoch 161/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2320.3186 - mean_absolute_error: 29.9621 - val_loss: 2515.4353 - val_mean_absolute_error: 30.9914
# Epoch 162/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2325.1587 - mean_absolute_error: 29.8608 - val_loss: 2256.5657 - val_mean_absolute_error: 29.5330
# Epoch 163/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2453.4023 - mean_absolute_error: 30.8178 - val_loss: 2548.5801 - val_mean_absolute_error: 30.3780
# Epoch 164/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2416.3484 - mean_absolute_error: 30.7353 - val_loss: 2630.7573 - val_mean_absolute_error: 32.8639
# Epoch 165/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2344.0532 - mean_absolute_error: 29.8842 - val_loss: 2412.7937 - val_mean_absolute_error: 31.2110
# Epoch 166/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2382.7961 - mean_absolute_error: 30.2178 - val_loss: 2486.8066 - val_mean_absolute_error: 33.1878
# Epoch 167/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2358.5920 - mean_absolute_error: 29.6780 - val_loss: 2265.4163 - val_mean_absolute_error: 28.7925
# Epoch 168/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2398.4778 - mean_absolute_error: 30.1060 - val_loss: 2531.4343 - val_mean_absolute_error: 32.2331
# Epoch 169/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2300.4231 - mean_absolute_error: 29.5527 - val_loss: 2622.7795 - val_mean_absolute_error: 31.1273
# Epoch 170/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2394.8770 - mean_absolute_error: 30.1086 - val_loss: 2371.9675 - val_mean_absolute_error: 30.2748
# Epoch 171/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2273.3857 - mean_absolute_error: 29.5883 - val_loss: 2316.6797 - val_mean_absolute_error: 29.3711
# Epoch 172/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2372.3320 - mean_absolute_error: 30.1139 - val_loss: 2420.2578 - val_mean_absolute_error: 31.7863
# Epoch 173/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2462.8096 - mean_absolute_error: 30.6473 - val_loss: 2437.9773 - val_mean_absolute_error: 30.5198
# Epoch 174/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2282.6641 - mean_absolute_error: 29.3000 - val_loss: 2287.5964 - val_mean_absolute_error: 29.2117
# Epoch 175/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2407.0042 - mean_absolute_error: 30.1438 - val_loss: 2369.6035 - val_mean_absolute_error: 29.8836
# Epoch 176/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2321.9497 - mean_absolute_error: 29.6950 - val_loss: 2655.7903 - val_mean_absolute_error: 33.1100
# Epoch 177/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2348.4951 - mean_absolute_error: 29.8092 - val_loss: 2256.3467 - val_mean_absolute_error: 29.6201
# Epoch 178/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2282.4712 - mean_absolute_error: 29.3541 - val_loss: 2319.0186 - val_mean_absolute_error: 30.0736
# Epoch 179/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2243.3164 - mean_absolute_error: 29.0837 - val_loss: 2271.1851 - val_mean_absolute_error: 29.8693
# Epoch 180/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2386.9102 - mean_absolute_error: 29.9110 - val_loss: 2252.2332 - val_mean_absolute_error: 29.0192
# Epoch 181/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2280.6907 - mean_absolute_error: 29.3223 - val_loss: 2513.7166 - val_mean_absolute_error: 33.0129
# Epoch 182/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2358.5364 - mean_absolute_error: 30.2754 - val_loss: 2254.0691 - val_mean_absolute_error: 29.2954
# Epoch 183/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2332.8457 - mean_absolute_error: 29.4268 - val_loss: 2348.2275 - val_mean_absolute_error: 30.3564
# Epoch 184/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2307.7156 - mean_absolute_error: 29.6623 - val_loss: 2269.1392 - val_mean_absolute_error: 29.2521
# Epoch 185/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2230.1521 - mean_absolute_error: 29.1350 - val_loss: 2412.8901 - val_mean_absolute_error: 30.2685
# Epoch 186/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2407.9817 - mean_absolute_error: 30.2634 - val_loss: 2319.7610 - val_mean_absolute_error: 30.3501
# Epoch 187/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2289.8552 - mean_absolute_error: 29.4158 - val_loss: 2281.0649 - val_mean_absolute_error: 28.9280
# Epoch 188/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2450.9573 - mean_absolute_error: 30.3065 - val_loss: 2269.0295 - val_mean_absolute_error: 30.3580
# Epoch 189/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2280.8555 - mean_absolute_error: 29.3812 - val_loss: 2506.1201 - val_mean_absolute_error: 32.4914
# Epoch 190/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2238.4958 - mean_absolute_error: 29.1100 - val_loss: 2277.5251 - val_mean_absolute_error: 29.3262
# Epoch 191/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2246.0247 - mean_absolute_error: 29.1761 - val_loss: 2197.6670 - val_mean_absolute_error: 29.2395
# Epoch 192/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2356.8035 - mean_absolute_error: 29.8088 - val_loss: 2304.3335 - val_mean_absolute_error: 30.7378
# Epoch 193/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2311.6035 - mean_absolute_error: 29.3687 - val_loss: 2227.7864 - val_mean_absolute_error: 28.8727
# Epoch 194/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2280.7212 - mean_absolute_error: 29.3021 - val_loss: 2180.1975 - val_mean_absolute_error: 29.3446
# Epoch 195/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2225.7285 - mean_absolute_error: 29.0600 - val_loss: 2815.3457 - val_mean_absolute_error: 34.5531
# Epoch 196/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2361.5654 - mean_absolute_error: 29.7659 - val_loss: 2261.7156 - val_mean_absolute_error: 30.5224
# Epoch 197/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2257.9231 - mean_absolute_error: 29.1058 - val_loss: 2381.4907 - val_mean_absolute_error: 30.7030
# Epoch 198/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2209.2676 - mean_absolute_error: 28.8839 - val_loss: 2245.1497 - val_mean_absolute_error: 29.3234
# Epoch 199/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2314.3555 - mean_absolute_error: 29.3732 - val_loss: 2341.9868 - val_mean_absolute_error: 29.0406
# Epoch 200/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2280.9426 - mean_absolute_error: 29.4062 - val_loss: 2286.6018 - val_mean_absolute_error: 29.6116
# Epoch 201/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2192.5349 - mean_absolute_error: 28.8045 - val_loss: 2614.8455 - val_mean_absolute_error: 31.1291
# Epoch 202/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2342.7285 - mean_absolute_error: 29.5007 - val_loss: 2213.7632 - val_mean_absolute_error: 29.4679
# Epoch 203/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2352.6152 - mean_absolute_error: 29.8045 - val_loss: 2205.0693 - val_mean_absolute_error: 28.5647
# Epoch 204/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2325.8228 - mean_absolute_error: 29.4055 - val_loss: 2267.4976 - val_mean_absolute_error: 29.8984
# Epoch 205/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2311.5439 - mean_absolute_error: 29.7256 - val_loss: 2953.6116 - val_mean_absolute_error: 38.2472
# Epoch 206/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2333.9155 - mean_absolute_error: 29.9364 - val_loss: 2214.0425 - val_mean_absolute_error: 29.3061
# Epoch 207/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2269.8428 - mean_absolute_error: 29.2782 - val_loss: 2364.8298 - val_mean_absolute_error: 29.5731
# Epoch 208/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2220.6011 - mean_absolute_error: 28.8982 - val_loss: 2155.9644 - val_mean_absolute_error: 28.4321
# Epoch 209/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2257.3174 - mean_absolute_error: 29.3917 - val_loss: 2242.0920 - val_mean_absolute_error: 29.9039
# Epoch 210/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2262.3955 - mean_absolute_error: 29.1816 - val_loss: 2259.4065 - val_mean_absolute_error: 28.6039
# Epoch 211/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2234.8320 - mean_absolute_error: 28.6535 - val_loss: 2323.4690 - val_mean_absolute_error: 29.4100
# Epoch 212/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2231.5481 - mean_absolute_error: 28.8896 - val_loss: 2197.7954 - val_mean_absolute_error: 29.7975
# Epoch 213/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2201.4900 - mean_absolute_error: 28.7505 - val_loss: 2595.2449 - val_mean_absolute_error: 33.7145
# Epoch 214/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2258.7444 - mean_absolute_error: 29.5287 - val_loss: 2577.4866 - val_mean_absolute_error: 31.3280
# Epoch 215/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2297.9785 - mean_absolute_error: 29.3187 - val_loss: 2222.4568 - val_mean_absolute_error: 29.4071
# Epoch 216/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2169.6733 - mean_absolute_error: 28.6139 - val_loss: 2375.4617 - val_mean_absolute_error: 31.2462
# Epoch 217/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2204.8184 - mean_absolute_error: 29.1710 - val_loss: 2543.8381 - val_mean_absolute_error: 31.9200
# Epoch 218/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2284.9734 - mean_absolute_error: 29.3886 - val_loss: 2227.5688 - val_mean_absolute_error: 29.0797
# Epoch 219/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2229.1199 - mean_absolute_error: 28.9565 - val_loss: 2214.0945 - val_mean_absolute_error: 28.9420
# Epoch 220/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2189.1626 - mean_absolute_error: 28.9181 - val_loss: 2583.7478 - val_mean_absolute_error: 32.1088
# Epoch 221/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2219.4321 - mean_absolute_error: 29.1044 - val_loss: 2548.6101 - val_mean_absolute_error: 32.3134
# Epoch 222/500
# 85/85 [==============================] - 0s 1ms/step - loss: 2330.3411 - mean_absolute_error: 29.7381 - val_loss: 3019.8176 - val_mean_absolute_error: 36.4156
# Epoch 223/500
# 85/85 [==============================] - 0s 2ms/step - loss: 2353.8357 - mean_absolute_error: 29.8590 - val_loss: 2229.6619 - val_mean_absolute_error: 29.0259

# %%
plt.figure(figsize=(8, 6))
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(np.linspace(0, len(y_valid), len(y_valid)), y_valid.values, label="MLP actual NOx(GT) values(validation)")
plt.plot(np.linspace(0, len(y_valid), len(y_valid)), model_regression.predict(X_valid), color="orange", label="MLP predict NOx(GT) values(validation)")
plt.xlabel('Epochs')
plt.ylabel('value')
plt.legend()
plt.show()
# Out:
# 43/43 [==============================] - 0s 713us/step

# %%
RMSE = np.sqrt(mean_squared_error(y_valid, model_regression.predict(X_valid)))
MAE = mean_absolute_error(y_valid, model_regression.predict(X_valid))
print("  RMSE  |   MAE    | Number_of_samples")
print(f"{RMSE:.4f} | {MAE:.4f}  |    {len(y_valid)}")
# Out:
# 43/43 [==============================] - 0s 428us/step
# 43/43 [==============================] - 0s 372us/step
#   RMSE  |   MAE    | Number_of_samples
# 46.2401 | 28.4321  |    1357

# %%
model_regression.save("regression_model.h5")
# Out:
# c:\ProgramData\anaconda3\envs\tensorflow\lib\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# ## processing of the test dataset

# %%
# test = pd.read_csv("test.csv")
# features_CO = df_preCO_train.columns
# features_NOx = df_preNOx_train.columns
# X_preCO_test = test[features_CO]
# X_preNOx_test = test[features_NOx]
# _, X_preNOx_test = minmax(X_totest_preNOx, X_preNOx_test)
# _, X_preCO_test = minmax(X_totest_preCO, X_preCO_test)
# X_preCO_test = poly_class.transform(X_preCO_test)
# X_preNOx_test = poly_reg.transform(X_preNOx_test)
# y_preCO_test = model_classification(X_preCO_test)
# y_preNOx_test = model_regression(X_preNOx_test)
